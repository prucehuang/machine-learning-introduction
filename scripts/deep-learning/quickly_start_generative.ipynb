# %%
import keras
import tensorflow
print(keras.__version__)
print(tensorflow.__version__)
# Out:
# 2.4.3
# 2.4.1

# %% [markdown]
# # LSTM生成文本

# %%
import keras
import numpy as np
# 默认保存路径 ~/.keras/datasets/nietzsche.txt

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# Corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

keras.utils.plot_model(model, "../../pic/my_model.png", show_shapes=True)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 6):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 95s 60ms/step - loss: 2.2738
# --- Generating with seed: ", for the sake of pleasure, as their
# conduct indicated--and "
# ------ temperature: 0.2
# , for the sake of pleasure, as their
# conduct indicated--and the atter the sen of the will the grome the convertion of the sen one of the say the self the promines of the sen of the any one of the sen one of the morality of the sen one of the series of the sen of the conscience of the a morality and the more the sen one of the sen one of the sen one of the morality of the conscience of the existing of the with the prodong the constinct of the sen one and th
# ------ temperature: 0.5
#  of the with the prodong the constinct of the sen one and the might with man, a monic are contemption of the would of a the conscience of its of it such more into the grades and every the good the becomed thing is thright, the great of any lare to a lack and exception of its himself in see strong in the are the the comperies of the regroding the sen of the aster exerting in the life himself of himself truth, the our and the bea lan in the wear to all the s
# ------ temperature: 1.0
# self truth, the our and the bea lan in the wear to all the soul mpare the detercons--muturoused the
# himivid as its from and things, again ordiessly fere us thome,
# things to (ackinged we : as that would thing to "admelable to have there higher such heek are hridverots (ot the grought, realf-into pladson by. for existrice and for hing, which wime accious altulanic mabne of landoul--premanical to
# cpry remirats how may also
# that plarent the hasted to nature of
# ------ temperature: 1.2
# y remirats how may also
# that plarent the hasted to nature of thestis" there: moranions ol wick very an igrigrw,
# one clane aganisseful and in"the caxess. abonament conccaenqukieg are every hard that which they giviture. but
# mution all witners: thy him
# every
# hacs ane owh subtiven nour
# the evilwobe," notonliched whemun ablievairiticery, to
# there overry and
# thinkshibus; spirit ]recess,," get unto. and confuncealtjor, its whakenownd,
# ffrind? who
# toke of cun das
# epoch 2
# 1565/1565 [==============================] - 168s 107ms/step - loss: 1.6128
# --- Generating with seed: "turies. why was this forgotten in our own century, during
# wh"
# ------ temperature: 0.2
# turies. why was this forgotten in our own century, during
# which is the spirit is it is a soul and the deature of the sentering the specially and the deached the spirit is not the the be deed and the most reason and the spirit it is the seated of the spirit to the specially for the deam the strong of the one of the strong the entire and the acture of the spirit and in every strong of the fact in the spirit to the deamed and the most not the moral and interp
# ------ temperature: 0.5
# e spirit to the deamed and the most not the moral and interpated interpretation of the reason of all contention of the reason and searity and soul of ears to an attathes that "upon the only and not a methes in every plation of the propect that a perhaps, and in the plached there and an allogical to an antempation of the pain and moralition of a deacher of the masters to deed of his virtue his spirit to the by an are the morality of "the spring to have be g
# ------ temperature: 1.0
# it to the by an are the morality of "the spring to have be gurm mestar flessed in the naw are lofedy and nom, of manitosial sime himders kence of chemm a hede, be them:extristrugn if not voll thrick, therebyduement to keroc of the ericated virw).
# us highine great of ht2ke
# syfeept, and in
# these arulse
# itself natural a
# strangut", and other heir
# partificide of unitidated these euroberhious as is noble thum and
# because. but mystloped be nowmands,
# vivitity ser
# ------ temperature: 1.2
# le thum and
# because. but mystloped be nowmands,
# vivitity serigionial calses, like out case trusceds te misterar be pur"eaked, is fa has feels of the stilp tumcusdiry and thosex is namble sechand and witshomy intellecsuts is
# in inotherluriug hervetuals of ulility ruse, in much
# christes mosttarilitary contint, firde": lus. but thuser: that they becidem,
#   : what suspecians of evely prowes gin their
# offouthily--we wandein dearopamabbe.
#
#
# 3pe
# yecs must only of
# epoch 3
# 1565/1565 [==============================] - 95s 60ms/step - loss: 1.5279
# --- Generating with seed: "ason of delight!
#                       my summer's park!
#    "
# ------ temperature: 0.2
# ason of delight!
#                       my summer's park!
#
# ------ temperature: 0.5
#
# ------ temperature: 1.0
#                                                               veuch so mind he conscition on more,,
# our lofk by more
# condition; i not rears bat acts and tawopr the our poof
# dies can no his men a" and dangersheness, moyesth and simpliated to be prwyo2s
# at the ppupjude even no lather begoners
# aimase
# she persisted he has with only ffor eary soul-brothing "pare of evil and oldismanl. the same a soughty of
# calual valition, so judgilants, no last what weoe.
#
# cer
# ------ temperature: 1.2
# y of
# calual valition, so judgilants, no last what weoe.
#
# certag of to christianitical! to be gnencedhel off, ouedeal brin? dive like him haftion), rumety awly that gueds so moundam: as werther if is not
# begniously ingenen, and deformed
# dpolie--in is in who dole than about trieve, and tyurces. it new shpede, nole is strongund of learneder himself as
# that whether the ha)d muth man
# sychological, under
# any-knoe during could innamily to dangen oucplaitioned,
# an
# epoch 4
# 1565/1565 [==============================] - 95s 60ms/step - loss: 1.4810
# --- Generating with seed: "ch in the general
# estimate of conduct are rated the best and"
# ------ temperature: 0.2
# ch in the general
# estimate of conduct are rated the best and strength of the man and distrust and religion of the morality of the master of the same interror of the world to the conduct of the development of the more to the morality of the sour and so conduct of the conscious of the conscious of the morality of them and all the same has to the most and sublimis of the morality of the same and any hable and believe of the conduct of the conduct is a proper
# ------ temperature: 0.5
# hable and believe of the conduct of the conduct is a proper and day, and the latter and stronger and to the definition of distinctely believe of the commonment them and propers of human something of unity of the commongrication of light, and is any condition of sublime in the same assible to them our present and deceited and them--i more be the cause of willing in the socre of the rele to be entire and more one socredible believe to the morality of the man
# ------ temperature: 1.0
# e and more one socredible believe to the morality of the mangers. on "the some
# namily frich them and praimpoordandang new ether circumsurness, frieffor within subledave, for the onesely in this wat of :ransed in the terrih, on the firlizn frame-elfeng "ffeble! yet the wablt also even se:
# free only has now thy xetuet; they had fregting thosucbe" of woman
# discreption. that his will wron and elong propice" of the
# ped of a riddly a, the praes marred and in
# the
# ------ temperature: 1.2
# opice" of the
# ped of a riddly a, the praes marred and in
# the knows, ground that hequigation of condling; no more
# traverness reed litt, oriately ye more bantoring, but the ever ask changer of light to with simply grow hunger to believe to dewer hanks; he has to a rang!
#
# .imet. )et the provent of lide order to beget., sometherisitu-earth is can transalways them"wall the fartivally even in the serve willings:
# my impre of those conscivating and ingarmanse, wat
# epoch 5
# 1565/1565 [==============================] - 95s 60ms/step - loss: 1.4506
# --- Generating with seed: " and
# more tact for reverence among the people, among the low"
# ------ temperature: 0.2
#  and
# more tact for reverence among the people, among the lower and soul and the spirit and the soul and the state of the spirit of the most depths of the same intererty of the develope of the most problem of the souls, and and the long the strong the most man in the spirit of the most and strong the develope of the conduct in the strong to the most profound the most spirit of the condition of the states and morality of the conduct as a man a man and to the
# ------ temperature: 0.5
# states and morality of the conduct as a man a man and to the souls, and the desires to be and the evil of contral to be are to say. the mad time to the way to that
# the state and depths in repended to the decides and find to the dopise desires and mistaken to be freedom with the deed of the word to the act of the word in its apparent of the states and that it is a far function has to the man in the spring of the commanding to himself and
# interest from the s
# ------ temperature: 1.0
#  spring of the commanding to himself and
# interest from the self-symptabting through felo-omans everything great in understand retir
# one writles hose for the spirits of
# aserly unreldisc. to let virity.
#
# in workers? the
# stre nubephorism onis, chast it as sufforing who much possibility with its schopebay babickness, these natuinagbre? the endural strengthos. the sentiment and interert
# impulsive hatiag dawble frating,? will geniuss, have good too who altast
# wh
# ------ temperature: 1.2
# g dawble frating,? will geniuss, have good too who altast
# which redured
# itself organish and regard the same to rialvationful some
# to
# be religion great fashigh.f, as away first here everyog exactact homasy, in-ploxe its cas dispersive dieftent (fals, who has moturr, to expleatunes. "some
# traverwically ethic
# revels
# expreences certain to becom rank, for
# no blembern according to typps to than of his vanits would befm he gladaringh, we most dgos the babeltny, f

# %% [markdown]
# # DeepDream生成图像

# %%
from keras.applications import inception_v3
from keras import backend as K

# We will not be training our model,
# so we use this command to disable all training-specific operations
K.set_learning_phase(0)

# Build the InceptionV3 network.
# The model will be loaded with pre-trained ImageNet weights.
model = inception_v3.InceptionV3(weights='imagenet',
                                 include_top=False)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:434: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 50s 1us/step

# %%
# Dict mapping layer names to a coefficient
# quantifying how much the layer's activation
# will contribute to the loss we will seek to maximize.
# Note that these are layer names as they appear
# in the built-in InceptionV3 application.
# You can list all layer names using `model.summary()`.
layer_contributions = {
    'mixed2': 0.2,
    'mixed3': 3.,
    'mixed4': 2.,
    'mixed5': 1.5,
}

# %%
# Get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# Define the loss.
loss = K.variable(0.)
for layer_name in layer_contributions:
    # Add the L2 norm of the features of a layer to the loss.
    coeff = layer_contributions[layer_name]
    activation = layer_dict[layer_name].output

    # We avoid border artifacts by only involving non-border pixels in the loss.
    scaling = K.prod(K.cast(K.shape(activation), 'float32'))
    loss = loss + coeff * K.sum(K.square(activation[:, 2: -2, 2: -2, :])) / scaling

# %%
# This holds our generated image
dream = model.input

# Compute the gradients of the dream with regard to the loss.
grads = K.gradients(loss, dream)[0]

# Normalize gradients.
grads /= K.maximum(K.mean(K.abs(grads)), 1e-7)

# Set up function to retrieve the value
# of the loss and gradients given an input image.
outputs = [loss, grads]
fetch_loss_and_grads = K.function([dream], outputs)

def eval_loss_and_grads(x):
    outs = fetch_loss_and_grads([x])
    loss_value = outs[0]
    grad_values = outs[1]
    return loss_value, grad_values

def gradient_ascent(x, iterations, step, max_loss=None):
    for i in range(iterations):
        loss_value, grad_values = eval_loss_and_grads(x)
        if max_loss is not None and loss_value > max_loss:
            break
        print('...Loss value at', i, ':', loss_value)
        x += step * grad_values
    return x
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-5a0aa6e642e0> in <module>
#       3
#       4 # Compute the gradients of the dream with regard to the loss.
# ----> 5 grads = K.gradients(loss, dream)[0]
#       6
#       7 # Normalize gradients.
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/backend.py in gradients(loss, variables)
#    4100       A gradients tensor.
#    4101   """
# -> 4102   return gradients_module.gradients(
#    4103       loss, variables, colocate_gradients_with_ops=True)
#    4104
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients)
#     167   # pylint: disable=protected-access
#     168   with ops.get_default_graph()._mutation_lock():
# --> 169     return gradients_util._GradientsHelper(
#     170         ys, xs, grad_ys, name, colocate_gradients_with_ops,
#     171         gate_gradients, aggregation_method, stop_gradients,
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gradients_util.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     490   """Implementation of gradients()."""
#     491   if context.executing_eagerly():
# --> 492     raise RuntimeError("tf.gradients is not supported when eager execution "
#     493                        "is enabled. Use tf.GradientTape instead.")
#     494   if src_graph is None:
#
# RuntimeError: tf.gradients is not supported when eager execution is enabled. Use tf.GradientTape instead.

# %%
import scipy
from keras.preprocessing import image

def resize_img(img, size):
    img = np.copy(img)
    factors = (1,
               float(size[0]) / img.shape[1],
               float(size[1]) / img.shape[2],
               1)
    return scipy.ndimage.zoom(img, factors, order=1)


def save_img(img, fname):
    pil_img = deprocess_image(np.copy(img))
    scipy.misc.imsave(fname, pil_img)


def preprocess_image(image_path):
    # Util function to open, resize and format pictures
    # into appropriate tensors.
    img = image.load_img(image_path)
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = inception_v3.preprocess_input(img)
    return img


def deprocess_image(x):
    # Util function to convert a tensor into a valid image.
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, x.shape[2], x.shape[3]))
        x = x.transpose((1, 2, 0))
    else:
        x = x.reshape((x.shape[1], x.shape[2], 3))
    x /= 2.
    x += 0.5
    x *= 255.
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import numpy as np

# Playing with these hyperparameters will also allow you to achieve new effects

step = 0.01  # Gradient ascent step size
num_octave = 3  # Number of scales at which to run gradient ascent
octave_scale = 1.4  # Size ratio between scales
iterations = 20  # Number of ascent steps per scale

# If our loss gets larger than 10,
# we will interrupt the gradient ascent process, to avoid ugly artifacts
max_loss = 10.

# Fill this to the path to the image you want to use
base_image_path = '/home/ubuntu/data/original_photo_deep_dream.jpg'

# Load the image into a Numpy array
img = preprocess_image(base_image_path)

# We prepare a list of shape tuples
# defining the different scales at which we will run gradient ascent
original_shape = img.shape[1:3]
successive_shapes = [original_shape]
for i in range(1, num_octave):
    shape = tuple([int(dim / (octave_scale ** i)) for dim in original_shape])
    successive_shapes.append(shape)

# Reverse list of shapes, so that they are in increasing order
successive_shapes = successive_shapes[::-1]

# Resize the Numpy array of the image to our smallest scale
original_img = np.copy(img)
shrunk_original_img = resize_img(img, successive_shapes[0])

for shape in successive_shapes:
    print('Processing image shape', shape)
    img = resize_img(img, shape)
    img = gradient_ascent(img,
                          iterations=iterations,
                          step=step,
                          max_loss=max_loss)
    upscaled_shrunk_original_img = resize_img(shrunk_original_img, shape)
    same_size_original = resize_img(original_img, shape)
    lost_detail = same_size_original - upscaled_shrunk_original_img

    img += lost_detail
    shrunk_original_img = resize_img(original_img, shape)
    save_img(img, fname='dream_at_scale_' + str(shape) + '.png')

save_img(img, fname='final_dream.png')

# %%
from matplotlib import pyplot as plt

plt.imshow(deprocess_image(np.copy(img)))
plt.show()

# %% [markdown]
# # 神经网络迁移
